# %%
range((0),(10)

# %%
xrange(0,9)

# %%
range(10)

# %%
x=range(0,10)

# %%
x

# %%
range()

# %%
l=[1,2,3,4,5]
for num in range(1,100):
    print (num)

# %%
xrange(1,6)

# %%
hello

# %%
print("hello")

# %%
#range(start,stop,step)

# %%
list(x)
