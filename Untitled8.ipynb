# %%
import csv
with open('walk-shoe.csv') as csvfile:
    readCSV=csv.reader(csvfile,delimiter=',')
    print(readCSV)
    for row in readCSV:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a78d90eaf45d> in <module>()
#       1 import csv
# ----> 2 with open('walk-shoe.csv') as csvfile:
#       3     readCSV=csv.reader(csvfile,delimiter=',')
#       4     print(readCSV)
#       5     for row in readCSV:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'walk-shoe.csv'

# %%
import csv
with open('walk-shoe.csv') as csvfile:
    readCSV=csv.reader(csvfile,delimiter=',')
    print(readCSV)
    for row in readCSV:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a78d90eaf45d> in <module>()
#       1 import csv
# ----> 2 with open('walk-shoe.csv') as csvfile:
#       3     readCSV=csv.reader(csvfile,delimiter=',')
#       4     print(readCSV)
#       5     for row in readCSV:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'walk-shoe.csv'

# %%
pwd
# Out:
# 'C:\\Users\\Sriman Rao'

# %%
import csv
with open('walk-shoe.csv') as csvfile:
    readCSV=csv.reader(csvfile,delimiter=',')
    print(readCSV)
    for row in readCSV:
        print(row)
# Out:
# ...
# ['Time since start in ms ', 'ACCELEROMETER X (m/sÂ²)', 'ACCELEROMETER Y (m/sÂ²)', 'ACCELEROMETER Z (m/sÂ²)']
# ['0', '1.0969', '9.7721', '0.614']
# ['20', '1.1146', '9.7501', '0.7444']
# ['40', '1.1146', '9.7501', '0.7444']
# ['60', '1.0124', '9.7151', '0.7169']
# ['79', '1.0124', '9.7151', '0.7169']
# ['100', '1.0927', '9.7324', '0.7356']
# ['120', '1.0927', '9.7324', '0.7356']
# ['139', '1.0865', '9.7029', '0.6958']
# ['160', '1.0865', '9.7029', '0.6958']
# ['180', '1.1562', '9.6978', '0.7881']
# ['200', '1.1562', '9.6978', '0.7881']
# ['220', '1.0872', '9.7332', '0.744']
# ['240', '1.0872', '9.7332', '0.744']
# ['260', '1.1393', '9.75', '0.669']
# ['280', '1.1393', '9.75', '0.669']
# ['300', '1.1371', '9.8413', '0.6875']
# ['320', '1.1371', '9.8413', '0.6875']
# ['339', '1.087', '9.6768', '0.7491']
# ['360', '1.087', '9.6768', '0.7491']
# ['380', '1.087', '9.6768', '0.7491']
# ['400', '1.0578', '9.6696', '0.8155']
# ['420', '1.0578', '9.6696', '0.8155']
# ...

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\SrimanRao\\walk-shoe.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-e74fd7ba7c00> in <module>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('C:\\Users\\SrimanRao\\walk-shoe.csv')
#       3 df
#
# ...
